# %% [markdown]
# # Problemas con los datos: entra basura, sale basura

# %% [markdown]
# ### Ejercicio 1: examine first 10 rows of a DB

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_raw.csv')

# Muestra las primeras 10 filas del DataFrame
print(df.head(10))

# %% [markdown]
# ### Ejercicio 2: print values of an specific column

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_raw.csv')

# Imprime los valores de la columna total play
print(df["total play"])
