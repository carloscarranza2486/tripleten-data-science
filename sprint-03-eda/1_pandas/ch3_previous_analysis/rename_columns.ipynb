# %% [markdown]
# # Rename columns

# %% [markdown]
# ### Guided practice

# %% [markdown]
# #### Exercise 1: Show columns

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_raw.csv')

columns = df.columns
print(columns)

# %% [markdown]
# #### Exercise 2: clean data

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_raw.csv')

new_columns = {
    '  user_id': 'user_id',
    'total play': 'total_play',
    'Artist': 'artist'
}

df_new_cols = df.rename(columns = new_columns)


print(df_new_cols.columns)

# %% [markdown]
# #### Exercise 3: inplace parameter usage

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_raw.csv')

# Renombrar las columnas utilizando el parámetro inplace
new_columns = {
    '  user_id': 'user_id',
    'total play': 'total_play',
    'Artist': 'artist'
}

df.rename(columns = new_columns, inplace = True)
print(df.columns)

# %% [markdown]
# #### Exercise 4: depurate spaces at column names

# %%
# Nombre de la columna con espacios en blanco
column_name = '  User_ID'

name_stripped = column_name.strip()

print(name_stripped)
# Out:
# User_ID

# %% [markdown]
# #### Exercise 5: Methods usage->lower

# %%
# Nombre de la columna con mayúsculas
column_name = 'User_ID'

name_lowered = column_name.lower()

print(name_lowered)

# %% [markdown]
# #### Exercise 6: Methods usage->replace

# %%
# Nombre de la columna con espacios internos
column_name = 'total play'

name_no_spaces = column_name.replace(" ","_")

print(name_no_spaces)

# %% [markdown]
# ## Practice activity

# %% [markdown]
# #### Exercise 1: Bucle's implementation

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_raw.csv')

new_col_names = []
for old_name in df.columns:
    name_stripped = old_name.strip()
    name_lowered = name_stripped.lower()
    name_no_spaces = name_lowered.replace(" ","_")
    new_col_names.append(name_no_spaces)

df.columns = new_col_names
print(df.columns)
