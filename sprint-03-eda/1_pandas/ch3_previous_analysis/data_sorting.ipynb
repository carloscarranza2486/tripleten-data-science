# %% [markdown]
# # Data sorting

# %% [markdown]
# ## Guided practice

# %% [markdown]
# #### Exercise 1: sort DB

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_processed.csv')

df_ordenado = df.sort_values(by = 'user_id', ascending = False)
print(df_ordenado.head(10))

# %% [markdown]
# #### Exercise 2: Sorted and filtered

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_processed.csv')

metal_ordenado = df[df['genre'] == 'metal'].sort_values(by = 'total_play', ascending = False)

print(metal_ordenado.head(10))

# %% [markdown]
# ## Practice activity

# %% [markdown]
# #### Exercise 1: sorted and filteres

# %%
import pandas as pd

df = pd.read_csv('/datasets/music_log_processed.csv')

time_by_genre = df.groupby('genre')['total_play'].sum()

time_by_genre_sort = time_by_genre.sort_values(ascending = False)

print(time_by_genre_sort.head(10))
