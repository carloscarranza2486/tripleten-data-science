# %% [markdown]
# # Custom filtering using query()

# %% [markdown]
# ## Guided practice

# %% [markdown]
# #### Exercise 1: filtering by 2 conditions (amount and country)

# %%
import pandas as pd

df = pd.read_csv('/datasets/vg_sales.csv')

print(df.query('jp_sales>1.0')[['name', 'jp_sales']])

# %% [markdown]
# #### Exercise 2: Filtering and returning specific columns using query

# %%
import pandas as pd

df = pd.read_csv('/datasets/vg_sales.csv')

cols = ['name', 'publisher', 'developer']

df_filtered = df.query("publisher == developer")[cols]
print(df_filtered.head())

# %% [markdown]
# #### Exercise 3: filtering with "not in" function using query

# %%
import pandas as pd

df = pd.read_csv('/datasets/vg_sales.csv')

handhelds = ['3DS', 'DS', 'GB', 'GBA', 'PSP']
print(df.query("platform not in @handhelds")[['name','platform']])

# %% [markdown]
# ## Practice activity

# %% [markdown]
# #### Exercise 1: Printing with unique method

# %%
import pandas as pd

df = pd.read_csv('/datasets/vg_sales.csv')

print(df['genre'].unique())

# %% [markdown]
# #### Exercise 2: Filtering using ~and isin() method

# %%
import pandas as pd

df = pd.read_csv('/datasets/vg_sales.csv')

cols = ['name', 'genre']
s_genres = ['Shooter', 'Simulation', 'Sports', 'Strategy']

df_filtered = df[~df['genre'].isin(s_genres)][cols]
print(df_filtered)

# %% [markdown]
# #### Exercise 3: excluding data using query from list of genre

# %%
import pandas as pd

df = pd.read_csv('/datasets/vg_sales.csv')

cols = ['name', 'genre']
s_genres = ['Shooter', 'Simulation', 'Sports', 'Strategy']

df_filtered = df.query("genre not in @s_genres")[cols]
# Filtra los géneros usando query() y not in

print(df_filtered)
