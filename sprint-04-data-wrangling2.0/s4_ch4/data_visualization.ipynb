# %% [markdown]
# # Lessons from bad visualizations

# %% [markdown]
# ## Example of chart made with python

# %%
import pandas as pd
import numpy as np

cases = [33, 61, 86, 112, 116, 129, 192, 174, 344, 304, 327, 246, 320, 339, 376]

dates = ['March<br>'] * len(cases)
day = 18
for i in range(len(dates)):
    dates[i] = dates[i] + str(day)
    day = day + 1
dates[-1] = 'April<br>1'

labels = dict(date="Date", cases="Number of cases")
markers = dict(size=30, line=dict(width=2, color='black'), color='white')
title = dict(text='New Cases Per Day', font=dict(color='white', size=30))
yaxis = dict(tickmode='linear', tick0=30, dtick=30)

df = pd.DataFrame({'cases': cases, 'date': dates})

fig = px.line(df, y='cases', x='date', text='cases', markers=True, labels=labels, title="New Cases Per Day")

fig.update_xaxes(showgrid=False, color='white', tickangle=0)
fig.update_yaxes(color='white', gridcolor='#5c5a5c', gridwidth=2, range=[15, 400])
fig.update_traces(marker=markers, line_color='white', line_width=6)
fig.update_layout(title=title,
                  title_x=0.5,
                  paper_bgcolor='#070230',
                  plot_bgcolor='#070230',
                  yaxis=yaxis,
                  xaxis_type='category')
fig.add_annotation(text='TOTAL CASES', 
                    align='right',
                    showarrow=False,
                    font=dict(color='white', size=12),
                    xref='paper',
                    yref='paper',
                    x=1.08,
                    y=1.25)
fig.add_annotation(text='3,342', 
                    align='right',
                    showarrow=False,
                    font=dict(color='white', size=23),
                    xref='paper',
                    yref='paper',
                    x=1.071,
                    y=1.2)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import plotly.express as px
#       5 cases = [33, 61, 86, 112, 116, 129, 192, 174, 344, 304, 327, 246, 320, 339, 376]
#       7 dates = ['March<br>'] * len(cases)
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # Creating graphs in Python with matplotlib

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})
print(df)

df.plot()
plt.show()
# Out:
#    a   b
# 0  2   4
# 1  3   9
# 2  4  16
# 3  5  25

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df['b'].plot()
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df['b'].plot()
plt.savefig('myplot.png')

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(title='A y B')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(title='A y B', style='o')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(title='A y B', style='x')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(title='A y B', style='o-')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(x='b', y='a', title='A vs B', style='o')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(x='b',
        y='a',
        title='A vs B',
        style='o',
        xlabel="Hola, soy B",
        ylabel="Hola, soy A")

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(x='b',
        y='a',
        title='A vs B',
        style='o',
        legend=False)

plt.xlabel("Hola, soy B") # configurando la leyenda x
plt.ylabel("Hola, so A") # configurando la leyenda y
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(x='b', y='a', title='A vs B', style='o', xlim=[0, 30], ylim=0)
# Out:
# <Axes: title={'center': 'A vs B'}, xlabel='b'>

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(x='b', y='a', title='A vs B', style='o', grid=True)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

# construir una gráfica pequeña
df.plot(x='b', y='a', style='o', xlim=[0, 30], figsize=[2, 2])

# construir una gráfica grande
df.plot(x='b', y='a', style='o', xlim=[0, 30], figsize=[10, 4])

plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# #### Exercise 1: Create chart with pink stars form

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25], 'c':[1, 3, 6, 10]})

df.plot(x="c", y="a", title='A vs C', style='*', color='hotpink', figsize=[5, 5],xlim=[0, 12], ylim=[1, 6], xlabel="C", ylabel="A")

plt.show()

# %% [markdown]
# ## Activity

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('/datasets/height_weight.csv')

df.plot(title="Adult heights", x="age", y="height", kind="scatter", alpha=0.36, figsize=[8, 6], xlabel="Age / years" , ylabel="Height / inches")

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('/datasets/height_weight.csv')

# separa df en dataframes separados según la edad
df_20s = df[df['age']<30]
df_30s = df[(df['age'] >= 30) & (df['age'] < 40)]
df_40s = df[df['age']>=40]

# print out the results
print("La suma de las longitudes del dataframe:", (len(df_20s) + len(df_30s) + len(df_40s)))
print("Edad mínima y máxima para df_20s:", (df_20s['age'].min()), (df_20s['age'].max()))
print("Edad mínima y máxima para df_30s:", (df_30s['age'].min()), (df_30s['age'].max()))
print("Edad mínima y máxima para df_40s:", (df_40s['age'].min()), (df_40s['age'].max()))

# %%
import pandas as pd
df_1 = pd.read_csv('/Users/carloscarranza/Downloads/instacart_orders.csv', sep=";")
print(df_1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
# None

# %%
print(df_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 74 columns):
#  #   Column                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                  --------------  -----
#  0   Handle                                                                                  269 non-null    object
#  1   Title                                                                                   61 non-null     object
#  2   Body (HTML)                                                                             61 non-null     object
#  3   Vendor                                                                                  61 non-null     object
#  4   Product Category                                                                        61 non-null     object
#  5   Type                                                                                    58 non-null     object
#  6   Tags                                                                                    10 non-null     object
#  7   Published                                                                               61 non-null     object
#  8   Option1 Name                                                                            61 non-null     object
#  9   Option1 Value                                                                           202 non-null    object
#  10  Option1 Linked To                                                                       41 non-null     object
#  11  Option2 Name                                                                            1 non-null      object
#  12  Option2 Value                                                                           4 non-null      object
#  13  Option2 Linked To                                                                       1 non-null      object
#  14  Option3 Name                                                                            0 non-null      float64
#  15  Option3 Value                                                                           0 non-null      float64
#  16  Option3 Linked To                                                                       0 non-null      float64
#  17  Variant SKU                                                                             0 non-null      float64
#  18  Variant Grams                                                                           202 non-null    float64
#  19  Variant Inventory Tracker                                                               202 non-null    object
#  20  Variant Inventory Qty                                                                   202 non-null    float64
#  21  Variant Inventory Policy                                                                202 non-null    object
#  22  Variant Fulfillment Service                                                             202 non-null    object
#  23  Variant Price                                                                           202 non-null    float64
#  24  Variant Compare At Price                                                                202 non-null    float64
#  25  Variant Requires Shipping                                                               202 non-null    object
#  26  Variant Taxable                                                                         202 non-null    object
#  27  Unit Price Total Measure                                                                23 non-null     float64
#  28  Unit Price Total Measure Unit                                                           23 non-null     object
#  29  Unit Price Base Measure                                                                 23 non-null     float64
#  30  Unit Price Base Measure Unit                                                            23 non-null     object
#  31  Variant Barcode                                                                         0 non-null      float64
#  32  Image Src                                                                               191 non-null    object
#  33  Image Position                                                                          191 non-null    float64
#  34  Image Alt Text                                                                          5 non-null      object
#  35  Gift Card                                                                               61 non-null     object
#  36  SEO Title                                                                               0 non-null      float64
#  37  SEO Description                                                                         0 non-null      float64
#  38  Google Shopping / Google Product Category                                               17 non-null     float64
#  39  Google Shopping / Gender                                                                0 non-null      float64
#  40  Google Shopping / Age Group                                                             30 non-null     object
#  41  Google Shopping / MPN                                                                   0 non-null      float64
#  42  Google Shopping / Condition                                                             0 non-null      float64
#  43  Google Shopping / Custom Product                                                        0 non-null      float64
#  44  Google Shopping / Custom Label 0                                                        0 non-null      float64
#  45  Google Shopping / Custom Label 1                                                        0 non-null      float64
#  46  Google Shopping / Custom Label 2                                                        0 non-null      float64
#  47  Google Shopping / Custom Label 3                                                        0 non-null      float64
#  48  Google Shopping / Custom Label 4                                                        0 non-null      float64
#  49  Google: Custom Product (product.metafields.mm-google-shopping.custom_product)           0 non-null      float64
#  50  Activewear clothing features (product.metafields.shopify.activewear-clothing-features)  9 non-null      object
#  51  Activity (product.metafields.shopify.activity)                                          15 non-null     object
#  52  Age group (product.metafields.shopify.age-group)                                        54 non-null     object
#  53  Best uses (product.metafields.shopify.best-uses)                                        4 non-null      object
#  54  Care instructions (product.metafields.shopify.care-instructions)                        4 non-null      object
#  55  Clothing features (product.metafields.shopify.clothing-features)                        21 non-null     object
#  56  Color (product.metafields.shopify.color-pattern)                                        57 non-null     object
#  57  Fabric (product.metafields.shopify.fabric)                                              61 non-null     object
#  58  Fit (product.metafields.shopify.fit)                                                    18 non-null     object
#  59  Neckline (product.metafields.shopify.neckline)                                          37 non-null     object
#  60  Outerwear clothing features (product.metafields.shopify.outerwear-clothing-features)    3 non-null      object
#  61  Pants length type (product.metafields.shopify.pants-length-type)                        20 non-null     object
#  62  Size (product.metafields.shopify.size)                                                  58 non-null     object
#  63  Skirt/Dress length type (product.metafields.shopify.skirt-dress-length-type)            4 non-null      object
#  64  Skirt style (product.metafields.shopify.skirt-style)                                    0 non-null      float64
#  65  Sleeve length type (product.metafields.shopify.sleeve-length-type)                      32 non-null     object
#  66  Target gender (product.metafields.shopify.target-gender)                                61 non-null     object
#  67  Top length type (product.metafields.shopify.top-length-type)                            25 non-null     object
#  68  Waist rise (product.metafields.shopify.waist-rise)                                      21 non-null     object
#  69  Variant Image                                                                           0 non-null      float64
#  70  Variant Weight Unit                                                                     202 non-null    object
#  71  Variant Tax Code                                                                        0 non-null      float64
#  72  Cost per item                                                                           181 non-null    float64
#  73  Status                                                                                  61 non-null     object
# dtypes: float64(29), object(45)
# memory usage: 155.6+ KB
# None

# %%
import pandas as pd
df_2 = pd.read_csv('/Users/carloscarranza/Downloads/products_export_1.csv')

# %%
#print(df_2.info())
print(df_2.head())
#print(df_2.isna().sum())
# Out:
#                                               Handle  \
# 0  the-inner-light-kampen-essentials-crewneck-cha...
# 1  the-inner-light-kampen-essentials-crewneck-cha...
# 2  the-inner-light-kampen-essentials-crewneck-cha...
# 3  the-inner-light-kampen-essentials-crewneck-cha...
# 4  the-inner-light-kampen-essentials-crewneck-cha...
#
#                                                Title  \
# 0  "The Inner Light" Kampen Essentials Crewneck –...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Body (HTML)  Vendor  \
# 0  <p data-path-to-node="3">Más que una prenda bá...  Kampen
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                     Product Category    Type Tags Published  \
# 0  Apparel & Accessories > Clothing > Clothing To...  Hoodie  NaN      True
# 1                                                NaN     NaN  NaN       NaN
# 2                                                NaN     NaN  NaN       NaN
# 3                                                NaN     NaN  NaN       NaN
# 4                                                NaN     NaN  NaN       NaN
#
#   Option1 Name Option1 Value  ...  \
# 0         Size             s  ...
# 1          NaN             m  ...
# 2          NaN             l  ...
# 3          NaN           NaN  ...
# 4          NaN           NaN  ...
#
#   Skirt style (product.metafields.shopify.skirt-style)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sleeve length type (product.metafields.shopify.sleeve-length-type)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Target gender (product.metafields.shopify.target-gender)  \
# 0                                             unisex
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Top length type (product.metafields.shopify.top-length-type)  \
# 0                                             medium
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Waist rise (product.metafields.shopify.waist-rise)  Variant Image  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    Variant Weight Unit  Variant Tax Code  Cost per item  Status
# 0                   kg               NaN        60000.0  active
# 1                   kg               NaN        60000.0     NaN
# 2                   kg               NaN        60000.0     NaN
# 3                  NaN               NaN            NaN     NaN
# 4                  NaN               NaN            NaN     NaN
#
# [5 rows x 74 columns]
